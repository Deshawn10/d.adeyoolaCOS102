# %%
# cell_9.py - Changing global variable inside function

def swap(x, y):
    global a  # Use global variable a
    a = "Lawal"
    x, y = y, x
    b = "Chris"
    b = "Edward"
    c = "Lola"
    print(a, b, x, y)

# Set a and call function
a = "Mary"
swap("Tina", "Tolu")
print(a)  # a is now changed to "Lawal"
