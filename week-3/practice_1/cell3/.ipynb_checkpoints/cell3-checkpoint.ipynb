# %%
# cell_3.py - Function that overwrites the list

def changeme(mylist):
    """This changes a passed list"""
    mylist = [1, 2, 3, 4]
    print("Values inside the function: ", mylist)
    return

# Create a list and call the function
mylist = [10, 20, 30]
changeme(mylist)
print("Values outside the function: ", mylist)
