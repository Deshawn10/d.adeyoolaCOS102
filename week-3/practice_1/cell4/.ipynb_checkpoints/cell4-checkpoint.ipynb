# %%
# cell_4.py - Function requires an argument

def printme(str):
    """This prints a passed string"""
    print(str)
    return

# This works
printme(str="My string")

# This would cause an error (uncomment to see)
# printme()  # Error: missing required argument
