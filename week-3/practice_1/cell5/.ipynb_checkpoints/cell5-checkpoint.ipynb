# %%
# cell_5.py - Using keyword arguments

def printinfo(name, age):
    """Test function"""
    print("Name: ", name)
    print("Age: ", age)
    return

# Call with arguments in different order
printinfo(age=50, name="miki")
