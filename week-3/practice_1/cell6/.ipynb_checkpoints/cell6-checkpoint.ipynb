# %%
# cell_6.py - Function with default argument

def printinfo(name, age=35):
    """Test function"""
    print("Name: ", name)
    print("Age: ", age)
    return

# Call with both arguments
printinfo(age=50, name="miki")

# Call without age (uses default)
printinfo(name="miki")
