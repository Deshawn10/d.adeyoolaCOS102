# %%
# Week_2/practice1.ipynb/cell_3 - List Operations
my_list = ['Anaconda', 786, 2.23, 'Jupyter', 70.2]
print(my_list)
print(my_list[0])
print(my_list[2:4])
print(my_list[3:])
print([321, 'Python'] * 2)
print(my_list + [321, 'Python'])
