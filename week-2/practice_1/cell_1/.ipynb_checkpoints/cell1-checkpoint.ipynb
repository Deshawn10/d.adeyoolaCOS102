# %%
# Week_2/practice1.ipynb/cell_1 - State of Origin Input
state_of_origin = input("Enter your state of origin: ")
print("Your state of origin is:", state_of_origin)
